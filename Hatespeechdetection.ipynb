# %% [markdown]
# <a href="https://colab.research.google.com/github/beimnet777/Automatic-Content-Moderation-Profanity-Filter-/blob/main/Hatespeechdetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data fetching and Shuffling

# %%
sentences=[]
labels=[]
with open("/content/Labels.txt","r") as csv_file:
  for row in csv_file:
    if row[0]=="F":
      labels.append(0)
    elif row[0]=="H":
      # print(row)
      labels.append(1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-c53f0cb7bdd7> in <cell line: 3>()
#       1 sentences=[]
#       2 labels=[]
# ----> 3 with open("/content/Labels.txt","r") as csv_file:
#       4   for row in csv_file:
#       5     if row[0]=="F":
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Labels.txt'

# %%
sentences_shuffled=[]
labels_shuffled=[]
for row,index in sentences:
  sentences_shuffled.append(row)
  labels_shuffled.append(labels[index])

# %%
print(len(sentences_shuffled),len(labels_shuffled),)
print(len(sentences),len(labels),sum(labels))

# %% [markdown]
# # Data Preprocessing using tokenizer and padding

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.text  import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
sentence_tokenizer=tf.keras.preprocessing.text.Tokenizer(oov_token="<oov>")
sentence_tokenizer.fit_on_texts(sentences_shuffled)

# %%
word_dict=sentence_tokenizer.word_index
word_dict
# Out:
# {'<oov>': 1,
#  'ነው': 2,
#  'ላይ': 3,
#  'ግን': 4,
#  'እና': 5,
#  'ህዝብ': 6,
#  'ምን': 7,
#  'ነገር': 8,
#  'ሰው': 9,
#  'አንተ': 10,
#  'ነበር': 11,
#  'ብቻ': 12,
#  'አማራ': 13,
#  'ነዉ': 14,
#  'ጋር': 15,
#  'አሁን': 16,
#  'እንደ': 17,
#  'ወደ': 18,
#  'ይህ': 19,
#  'ማለት': 20,
#  'እንጂ': 21,
#  'መንግስት': 22,
#  'አንድ': 23,
#  'ደግሞ': 24,
#  'እኮ': 25,
#  'ሁሉ': 26,
#  'በጣም': 27,
#  'እንኳን': 28,
#  'አይደለም': 29,
#  'ውስጥ': 30,
#  'ብሎ': 31,
#  'ለምን': 32,
#  'ሀገር': 33,
#  'እኔ': 34,
#  'የአማራ': 35,
#  'ናቸው': 36,
#  'ጥሩ': 37,
#  'ነህ': 38,
#  'ጊዜ': 39,
#  'ሳይሆን': 40,
#  'ብዙ': 41,
#  'ያለው': 42,
#  'ምንም': 43,
#  'የለም': 44,
#  'ልጅ': 45,
#  'አይነት': 46,
#  'በላይ': 47,
#  'እግዚአብሄር': 48,
#  'ስራ': 49,
#  'ይሄ': 50,
#  'እኛ': 51,
#  'እውነት': 52,
#  'አለ': 53,
#  'እንዴ': 54,
#  'ስለ': 55,
#  'እንዴት': 56,
#  'ኢትዮጵያ': 57,
#  'በዚህ': 58,
#  'ችግር': 59,
#  'አብይ': 60,
#  'ቀን': 61,
#  'ሁሉም': 62,
#  'እንዲህ': 63,
#  'ክልል': 64,
#  'ጉዳይ': 65,
#  'ሌላ': 66,
#  'ሀሳብ': 67,
#  'ይህን': 68,
#  'እንጅ': 69,
#  'ወይም': 70,
#  'ዝም': 71,
#  'ቤት': 72,
#  'አመት': 73,
#  'ብለህ': 74,
#  'ያለ': 75,
#  'ዛሬ': 76,
#  'አለበት': 77,
#  'ሰዎች': 78,
#  'የኢትዮጵያ': 79,
#  'ከሆነ': 80,
#  'አሁንም': 81,
#  'ነኝ': 82,
#  'ሆነ': 83,
#  'አይ': 84,
#  'ልክ': 85,
#  'ታሪክ': 86,
#  'መልካም': 87,
#  'ማን': 88,
#  'ስም': 89,
#  'ወይ': 90,
#  'ቢሆን': 91,
#  'መንገድ': 92,
#  'አገር': 93,
#  'ከዚህ': 94,
#  'ፖለቲካ': 95,
#  'እሱ': 96,
#  'ቦታ': 97,
#  'ደስ': 98,
#  'መሆን': 99,
#  'ፈጣሪ': 100,
#  'አበባ': 101,
#  'ሆኖ': 102,
#  'ገና': 103,
#  'የ': 104,
#  'ስልጣን': 105,
#  'የሆነ': 106,
#  'ነን': 107,
#  'እናንተ': 108,
#  'አዲስ': 109,
#  'ኦሮሞ': 110,
#  'ስለሆነ': 111,
#  'በ': 112,
#  'ጃዋር': 113,
#  'መሆኑን': 114,
#  'የሚል': 115,
#  'ከ': 116,
#  'ዘመን': 117,
#  'ስለዚህ': 118,
#  'ወያኔ': 119,
#  'ደሞ': 120,
#  'ማንም': 121,
#  'ትክክል': 122,
#  'ደም': 123,
#  'መሪ': 124,
#  'አሉ': 125,
#  'ምክንያቱም': 126,
#  'አቶ': 127,
#  'ጀግና': 128,
#  'ይሆናል': 129,
#  'አምላክ': 130,
#  'እነ': 131,
#  'እንደሆነ': 132,
#  'የኦሮሞ': 133,
#  'አለው': 134,
#  'እንደዚህ': 135,
#  'ይሁን': 136,
#  'ብለው': 137,
#  'ይችላል': 138,
#  'ይሆን': 139,
#  'ሚኪ': 140,
#  'የለውም': 141,
#  'የፖለቲካ': 142,
#  'እስከ': 143,
#  'አብን': 144,
#  'ማድረግ': 145,
#  'እምነት': 146,
#  'ምክንያት': 147,
#  'ይሄን': 148,
#  'እስኪ': 149,
#  'አለም': 150,
#  'በፊት': 151,
#  'የትግራይ': 152,
#  'ሰላም': 153,
#  'ምነው': 154,
#  'ትግራይ': 155,
#  'ቋንቋ': 156,
#  'ልጆች': 157,
#  'ዶር': 158,
#  'ህወሀት': 159,
#  'ሰአት': 160,
#  'ይገባል': 161,
#  'ምርጫ': 162,
#  'ና': 163,
#  'ድረስ': 164,
#  'የሰው': 165,
#  'ልደቱ': 166,
#  'ወይስ': 167,
#  'ክርስቲያን': 168,
#  'በቃ': 169,
#  'በኋላ': 170,
#  'ትልቅ': 171,
#  'ግዜ': 172,
#  'ዘመዴ': 173,
#  'ናት': 174,
#  'የት': 175,
#  'ቤተ': 176,
#  'ዳኒ': 177,
#  'ይላል': 178,
#  'ወሬ': 179,
#  'ይልቅ': 180,
#  'ሀይማኖት': 181,
#  'ያህል': 182,
#  'ለዚህ': 183,
#  'ብሄር': 184,
#  'እያለ': 185,
#  'በአንድ': 186,
#  'አንተን': 187,
#  'መሆኑ': 188,
#  'ኢትዮጵያን': 189,
#  'አንተም': 190,
#  'እነሱ': 191,
#  'ወንድሜ': 192,
#  'ትንሽ': 193,
#  'ኢትዮጵያዊ': 194,
#  'ሁኔታ': 195,
#  'እጅግ': 196,
#  'ሌባ': 197,
#  'አይደል': 198,
#  'ሁለት': 199,
#  'ሰዉ': 200,
#  'መግለጫ': 201,
#  'ይህንን': 202,
#  'መጀመሪያ': 203,
#  'ሁሌም': 204,
#  'አላህ': 205,
#  'በተለይ': 206,
#  'ሆይ': 207,
#  'መቼም': 208,
#  'ኦርቶዶክስ': 209,
#  'ደህና': 210,
#  'ለአማራ': 211,
#  'ጥያቄ': 212,
#  'የኛ': 213,
#  'ስንት': 214,
#  'ያለውን': 215,
#  'ህዝብን': 216,
#  'አማራን': 217,
#  'ህግ': 218,
#  'ፓርቲ': 219,
#  'መጣህ': 220,
#  'ውጭ': 221,
#  'የሚባል': 222,
#  'ዋጋ': 223,
#  'አንዱ': 224,
#  'እነዚህ': 225,
#  'ህዝቡ': 226,
#  'ሀይል': 227,
#  'ተብሎ': 228,
#  'ሌላው': 229,
#  'ይመስለኛል': 230,
#  'ለ': 231,
#  'በደንብ': 232,
#  'ሲሆን': 233,
#  'ልብ': 234,
#  'መብት': 235,
#  'የኔ': 236,
#  'ጠላት': 237,
#  'ሲል': 238,
#  'ነፃ': 239,
#  'የሚለው': 240,
#  'በሰላም': 241,
#  'በሙሉ': 242,
#  'እጅ': 243,
#  'ሙሉ': 244,
#  'ጥላቻ': 245,
#  'ወቅት': 246,
#  'ያለበት': 247,
#  'በርታ': 248,
#  'ግልፅ': 249,
#  'ብዬ': 250,
#  'ገንዘብ': 251,
#  'ያሉ': 252,
#  'ሁላ': 253,
#  'መረጃ': 254,
#  'በአማራ': 255,
#  'ተስፋ': 256,
#  'የአማራን': 257,
#  'እድሜ': 258,
#  'ሙስሊም': 259,
#  'ብር': 260,
#  'አማርኛ': 261,
#  'ዘር': 262,
#  'ምርጥ': 263,
#  'መልስ': 264,
#  'እያሉ': 265,
#  'ጥቅም': 266,
#  'ያው': 267,
#  'አድርጎ': 268,
#  'በል': 269,
#  'ያሳዝናል': 270,
#  'አረ': 271,
#  'እዚህ': 272,
#  'ለማንኛውም': 273,
#  'እንኳ': 274,
#  'መሬት': 275,
#  'አሜን': 276,
#  'የመንግስት': 277,
#  'አህመድ': 278,
#  'እረ': 279,
#  'ለማለት': 280,
#  'ቃል': 281,
#  'አይመስለኝም': 282,
#  'የህዝብ': 283,
#  'ካለ': 284,
#  'ጀምሮ': 285,
#  'ኧረ': 286,
#  'ቤተክርስቲያን': 287,
#  'ምክር': 288,
#  'ሌሎች': 289,
#  'ነገ': 290,
#  'እራሱ': 291,
#  'አይቀርም': 292,
#  'ያ': 293,
#  'ስርአት': 294,
#  'እኔም': 295,
#  'መልኩ': 296,
#  'ብርሀኑ': 297,
#  'ክብር': 298,
#  'ለኢትዮጵያ': 299,
#  'እኛም': 300,
#  'ነሽ': 301,
#  'ናችሁ': 302,
#  'እናመሰግናለን': 303,
#  'ከተማ': 304,
#  'እስቲ': 305,
#  'ቁጥር': 306,
#  'ብለን': 307,
#  'ለህዝብ': 308,
#  'ድርጅት': 309,
#  'ሞት': 310,
#  'ምድረ': 311,
#  'ይዞ': 312,
#  'በኩል': 313,
#  'አስተሳሰብ': 314,
#  'ጎንደር': 315,
#  'ጦርነት': 316,
#  'ይማር': 317,
#  'ህዝቡን': 318,
#  'ዳንኤል': 319,
#  'ፍቅር': 320,
#  'መምህር': 321,
#  'ሁሉንም': 322,
#  'ኖሮ': 323,
#  'ደረጃ': 324,
#  'ቄሮ': 325,
#  'አይቻልም': 326,
#  'ብልፅግና': 327,
#  'በትክክል': 328,
#  'መስራት': 329,
#  'ታዲያ': 330,
#  'ሴራ': 331,
#  'ባንዳ': 332,
#  'መንጋ': 333,
#  'የተሻለ': 334,
#  'በኢትዮጵያ': 335,
#  'ፅሁፍ': 336,
#  'ግራ': 337,
#  'አመታት': 338,
#  'ቁጭ': 339,
#  'ይሻላል': 340,
#  'ማየት': 341,
#  'አለኝ': 342,
#  'እንዲሁም': 343,
#  'ስር': 344,
#  'ታዴ': 345,
#  'ነውና': 346,
#  'ደደብ': 347,
#  'ለነገሩ': 348,
#  'አካል': 349,
#  'ትግል': 350,
#  'ያንተ': 351,
#  'ሲባል': 352,
#  'ይቅር': 353,
#  'ትግሬ': 354,
#  'ያኔ': 355,
#  'እንዳንተ': 356,
#  'ያሉት': 357,
#  'ወጣት': 358,
#  'አንበሳ': 359,
#  'አይችልም': 360,
#  'ጉድ': 361,
#  'ፊት': 362,
#  'ሰይጣን': 363,
#  'ነገሩ': 364,
#  'በምን': 365,
#  'ጠቅላይ': 366,
#  'አቅም': 367,
#  'ሰልፍ': 368,
#  'ከፍተኛ': 369,
#  'በቀለ': 370,
#  'ወንጀል': 371,
#  'አንቺ': 372,
#  'ዛሬም': 373,
#  'ተው': 374,
#  'መኖር': 375,
#  'ይመስላል': 376,
#  'ብላችሁ': 377,
#  'ነበረ': 378,
#  'ቢሆንም': 379,
#  'በራሱ': 380,
#  'ጋ': 381,
#  'በእውነት': 382,
#  'ከዛ': 383,
#  'ውሸት': 384,
#  'ዘንድ': 385,
#  'የለበትም': 386,
#  'ካልሆነ': 387,
#  'እሱን': 388,
#  'ዉስጥ': 389,
#  'አጀንዳ': 390,
#  'ውሀ': 391,
#  'አህያ': 392,
#  'ነፍስ': 393,
#  'መፍትሄ': 394,
#  'ምንድነው': 395,
#  'ብአዴን': 396,
#  'ለውጥ': 397,
#  'መቼ': 398,
#  'ትክክለኛ': 399,
#  'ምናምን': 400,
#  'አሜሪካ': 401,
#  'ምድር': 402,
#  'አቋም': 403,
#  'መሰረት': 404,
#  'ሰውን': 405,
#  'መስቀል': 406,
#  'አፍ': 407,
#  'ስህተት': 408,
#  'መለስ': 409,
#  'ተግባር': 410,
#  'ክፉ': 411,
#  'ታደለ': 412,
#  'በቂ': 413,
#  'ሊሆን': 414,
#  'ይቅርታ': 415,
#  'ነገሮች': 416,
#  'ባንዲራ': 417,
#  'ብየ': 418,
#  'አደባባይ': 419,
#  'ጎን': 420,
#  'አደለም': 421,
#  'ሲጀመር': 422,
#  'ማርያም': 423,
#  'ፋኖ': 424,
#  'ባለ': 425,
#  'ቡድን': 426,
#  'ትውልድ': 427,
#  'አካባቢ': 428,
#  'ይቻላል': 429,
#  'እውቀት': 430,
#  'ግፍ': 431,
#  'አንድነት': 432,
#  'ለካ': 433,
#  'ጌታ': 434,
#  'ያስፈልጋል': 435,
#  'ስዩም': 436,
#  'ለሁሉም': 437,
#  'የበለጠ': 438,
#  'ነች': 439,
#  'ከፍ': 440,
#  'ራሱ': 441,
#  'እርስ': 442,
#  'አብሮ': 443,
#  'ትምህርት': 444,
#  'መስጠት': 445,
#  'ድምፅ': 446,
#  'ውጪ': 447,
#  'እስክንድር': 448,
#  'ፎቶ': 449,
#  'አለን': 450,
#  'ዋና': 451,
#  'ህገ': 452,
#  'የወያኔ': 453,
#  'ተራ': 454,
#  'አንድም': 455,
#  'መቀሌ': 456,
#  'በመሆኑ': 457,
#  'ጭንቅላት': 458,
#  'ፖለቲከኛ': 459,
#  'እያልክ': 460,
#  'የነበረው': 461,
#  'አስቱ': 462,
#  'ካንተ': 463,
#  'ተዋህዶ': 464,
#  'አዴፓ': 465,
#  'ይገርማል': 466,
#  'ወገን': 467,
#  'የሀገር': 468,
#  'እናም': 469,
#  'በግልፅ': 470,
#  'ፍትህ': 471,
#  'ከአማራ': 472,
#  'ወንድም': 473,
#  'እስካሁን': 474,
#  'ፖለቲከኞች': 475,
#  'ለማድረግ': 476,
#  'ቆሻሻ': 477,
#  'እባካችሁ': 478,
#  'የአዲስ': 479,
#  'ቢያንስ': 480,
#  'ተገቢ': 481,
#  'ድንጋይ': 482,
#  'ባይ': 483,
#  'እናት': 484,
#  'እባክህ': 485,
#  'አቤት': 486,
#  'ነጋ': 487,
#  'ኦሮሚያ': 488,
#  'የኦርቶዶክስ': 489,
#  'መስመር': 490,
#  'ሁሌ': 491,
#  'አላማ': 492,
#  'አዎ': 493,
#  'ሁኖ': 494,
#  'ልዩ': 495,
#  'መች': 496,
#  'ያላቸው': 497,
#  'በሚል': 498,
#  'እኩል': 499,
#  'የሆነው': 500,
#  'እዛው': 501,
#  'የሀይማኖት': 502,
#  'ኦነግ': 503,
#  'ዜና': 504,
#  'አሳምነው': 505,
#  'ይባላል': 506,
#  'ታዬ': 507,
#  'ዶክተር': 508,
#  'የሚለውን': 509,
#  'ጤና': 510,
#  'አቦ': 511,
#  'ህዝቦች': 512,
#  'የታሪክ': 513,
#  'ለመሆኑ': 514,
#  'እራሱን': 515,
#  'አብይን': 516,
#  'ፀሎት': 517,
#  'ማሰብ': 518,
#  'ፍርድ': 519,
#  'ቅዱስ': 520,
#  'ዘረኛ': 521,
#  'ችግሩ': 522,
#  'በሀላ': 523,
#  'ነፍጠኛ': 524,
#  'እንግዲህ': 525,
#  'በአል': 526,
#  'ለማጥፋት': 527,
#  'ስሜት': 528,
#  'የአንድ': 529,
#  'አንዴ': 530,
#  'ሰውየው': 531,
#  'መፅሀፍ': 532,
#  'ከባድ': 533,
#  'አማራጭ': 534,
#  'የሌለው': 535,
#  'በማለት': 536,
#  'እውነተኛ': 537,
#  'በሽታ': 538,
#  'ሰውዬ': 539,
#  'አዋጅ': 540,
#  'ህይወት': 541,
#  'ወደፊት': 542,
#  'ለማ': 543,
#  'ንግግር': 544,
#  'አይነቱ': 545,
#  'ብሄራዊ': 546,
#  'ወዘተ': 547,
#  'መቸም': 548,
#  'በዛ': 549,
#  'ራስ': 550,
#  'አለህ': 551,
#  'ስብስብ': 552,
#  'ሙስሊሞች': 553,
#  'ድጋፍ': 554,
#  'እድል': 555,
#  'በሌላ': 556,
#  'ደንቆሮ': 557,
#  'የለህም': 558,
#  'ሚዲያ': 559,
#  'አይሆንም': 560,
#  'ናቸዉ': 561,
#  'ሰወች': 562,
#  'ቆይ': 563,
#  'የትም': 564,
#  'አቢይ': 565,
#  'ድል': 566,
#  'የምን': 567,
#  'የስራ': 568,
#  'ተረት': 569,
#  'አስተያየት': 570,
#  'የሚባለው': 571,
#  'መስኪ': 572,
#  'የሆኑ': 573,
#  'ተማሪዎች': 574,
#  'ጎበዝ': 575,
#  'ግድ': 576,
#  'መካከል': 577,
#  'እርምጃ': 578,
#  'በማድረግ': 579,
#  'ዘመድኩን': 580,
#  'ተላላኪ': 581,
#  'የኢትዮጵያን': 582,
#  'ማስረጃ': 583,
#  'ያማል': 584,
#  'ነበሩ': 585,
#  'ድርጊት': 586,
#  'ጭምር': 587,
#  'የአብይ': 588,
#  'አፄ': 589,
#  'አልባ': 590,
#  'አባት': 591,
#  'በሉ': 592,
#  'ቢኖር': 593,
#  'እንዳለ': 594,
#  'መሰለኝ': 595,
#  'ድሮ': 596,
#  'ሆነው': 597,
#  'ባለቤት': 598,
#  'ለምሳሌ': 599,
#  'ኮሮና': 600,
#  'መናገር': 601,
#  'ክፍል': 602,
#  'ለሀገር': 603,
#  'ከላይ': 604,
#  'ንጉስ': 605,
#  'ያክል': 606,
#  'ስትል': 607,
#  'የራሱን': 608,
#  'በህግ': 609,
#  'ማንነት': 610,
#  'ልቦና': 611,
#  'ሀገራችን': 612,
#  'ከብት': 613,
#  'ማነው': 614,
#  'ይሄንን': 615,
#  'አየር': 616,
#  'የሚገርመኝ': 617,
#  'አባቶች': 618,
#  'ውሻ': 619,
#  'በአለም': 620,
#  'ገነት': 621,
#  'ለፍርድ': 622,
#  'ላንተ': 623,
#  'መንፈስ': 624,
#  'ራሱን': 625,
#  'የለ': 626,
#  'ጨምሮ': 627,
#  'ትላለህ': 628,
#  'የውሸት': 629,
#  'እሳት': 630,
#  'ማወቅ': 631,
#  'ያኑርልን': 632,
#  'ወር': 633,
#  'አንተና': 634,
#  'ሴት': 635,
#  'ሀቅ': 636,
#  'አንዳንድ': 637,
#  'ኛ': 638,
#  'አይዞህ': 639,
#  'መከራ': 640,
#  'አለብን': 641,
#  'ለኛ': 642,
#  'ጠንካራ': 643,
#  'ወዳጄ': 644,
#  'ገደል': 645,
#  'በርቱ': 646,
#  'ተከታይ': 647,
#  'ድሮም': 648,
#  'የህወሀት': 649,
#  'አም': 650,
#  'ስጋት': 651,
#  'እይታ': 652,
#  'እናተ': 653,
#  'ከንቱ': 654,
#  'የስልጣን': 655,
#  'በገነት': 656,
#  'ሀላፊነት': 657,
#  'ልዩነት': 658,
#  'በጋራ': 659,
#  'ይስጥህ': 660,
#  'ወንድማችን': 661,
#  'ጥፋት': 662,
#  'በቅርቡ': 663,
#  'የእውነት': 664,
#  'መጥፎ': 665,
#  'ህውሀት': 666,
#  'ባዶ': 667,
#  'ዳር': 668,
#  'አፈር': 669,
#  'የዘር': 670,
#  'ከነ': 671,
#  'እውነትን': 672,
#  'ቀላል': 673,
#  'ያልከው': 674,
#  'ትርጉም': 675,
#  'ልደቱን': 676,
#  'ሆድ': 677,
#  'በለው': 678,
#  'አለባቸው': 679,
#  'ለይ': 680,
#  'እርግጠኛ': 681,
#  'ጭራሽ': 682,
#  'ሁላችንም': 683,
#  'አስቴር': 684,
#  'ሙሌ': 685,
#  'አልፎ': 686,
#  'አመራር': 687,
#  'የኦሮሚያ': 688,
#  'አካሄድ': 689,
#  'አክራሪ': 690,
#  'ጌታቸው': 691,
#  'ታላቅ': 692,
#  'ታድያ': 693,
#  'ነገሮችን': 694,
#  'ደጋፊ': 695,
#  'ፀረ': 696,
#  'ቴዎድሮስ': 697,
#  'የሚሉት': 698,
#  'አይደሉም': 699,
#  'ደነዝ': 700,
#  'እኔን': 701,
#  'አስፈላጊ': 702,
#  'አስተዳደር': 703,
#  'ዋናው': 704,
#  'አማሮች': 705,
#  'ወጣቶች': 706,
#  'ክርስቶስ': 707,
#  'በሀይማኖት': 708,
#  'ቀርቶ': 709,
#  'ማጥፋት': 710,
#  'የአለም': 711,
#  'ሰሞኑን': 712,
#  'መስከረም': 713,
#  'ዜጋ': 714,
#  'እዛ': 715,
#  'ብላ': 716,
#  'ያንተን': 717,
#  'ዝቅ': 718,
#  'ግለሰብ': 719,
#  'ሲሉ': 720,
#  'ትላንት': 721,
#  'አንፃር': 722,
#  'ያሳያል': 723,
#  'አዋቂ': 724,
#  'ሆነህ': 725,
#  'ሀብት': 726,
#  'እዉነት': 727,
#  'መሳሪያ': 728,
#  'መከላከያ': 729,
#  'እንዲ': 730,
#  'ኪሎ': 731,
#  'በሰው': 732,
#  'ፈፅሞ': 733,
#  'ፍፁም': 734,
#  'ቃላት': 735,
#  'ሌላውን': 736,
#  'እውነቱን': 737,
#  'ውጤት': 738,
#  'መርዝ': 739,
#  'እግር': 740,
#  'የነበረ': 741,
#  'መልእክት': 742,
#  'ውሳኔ': 743,
#  'ፓርላማ': 744,
#  'ሄኖክ': 745,
#  'ስዩሜ': 746,
#  'ሀይሎች': 747,
#  'ያውቃል': 748,
#  'የሚሉ': 749,
#  'ማቅረብ': 750,
#  'ትልቁ': 751,
#  'ቀድሞ': 752,
#  'ሁሉን': 753,
#  'መንግስቱ': 754,
#  'መቸ': 755,
#  'አሁንስ': 756,
#  'ለኔ': 757,
#  'እሱም': 758,
#  'ከዚያ': 759,
#  'ይሄው': 760,
#  'አቀፍ': 761,
#  'መሰል': 762,
#  'ፓለቲካ': 763,
#  'ገብቶ': 764,
#  'አያውቅም': 765,
#  'ገዱ': 766,
#  'ወሳኝ': 767,
#  'ከየት': 768,
#  'ማህበረሰብ': 769,
#  'ድንቅ': 770,
#  'አራት': 771,
#  'የዚህ': 772,
#  'ፖሊስ': 773,
#  'ነፃነት': 774,
#  'ተቀባይነት': 775,
#  'አደጋ': 776,
#  'ምልክት': 777,
#  'አመራሮች': 778,
#  'ዙሪያ': 779,
#  'ሀብታሙ': 780,
#  'እውነትም': 781,
#  'ባህር': 782,
#  'ቶሎ': 783,
#  'ይኸው': 784,
#  'የናንተ': 785,
#  'ያን': 786,
#  'አክቲቪስት': 787,
#  'ለመሆን': 788,
#  'ቤቱ': 789,
#  'የሚሆነው': 790,
#  'በህዝብ': 791,
#  'እነዚህን': 792,
#  'አገራችን': 793,
#  'የተለየ': 794,
#  'ዘመቻ': 795,
#  'የተዋህዶ': 796,
#  'ጎጃም': 797,
#  'ይዘህ': 798,
#  'የሚገርመው': 799,
#  'በፍፁም': 800,
#  'የነበረውን': 801,
#  'የነበሩ': 802,
#  'መታወቂያ': 803,
#  'በአማርኛ': 804,
#  'የበላይነት': 805,
#  'ግድብ': 806,
#  'እስልምና': 807,
#  'ነፍሳቸውን': 808,
#  'ንብረት': 809,
#  'እየሰራ': 810,
#  'እሺ': 811,
#  'ገዳይ': 812,
#  'ጥግ': 813,
#  'የለኝም': 814,
#  'አጋጣሚ': 815,
#  'አይን': 816,
#  'ባክህ': 817,
#  'ይላሉ': 818,
#  'ውይይት': 819,
#  'እነሱን': 820,
#  'ፍላጎት': 821,
#  'ዘረኝነት': 822,
#  'እስር': 823,
#  'መሀል': 824,
#  'ያለዉ': 825,
#  'እለት': 826,
#  'አሸባሪ': 827,
#  'ያውም': 828,
#  'ከህዝብ': 829,
#  'ያሉትን': 830,
#  'አድርገህ': 831,
#  'ተቋም': 832,
#  'ሄዶ': 833,
#  'በአዲስ': 834,
#  'ተመስገን': 835,
#  'በሀሳብ': 836,
#  'ፊደል': 837,
#  'መሀይም': 838,
#  'የእግዚአብሄር': 839,
#  'ምንድን': 840,
#  'ምስኪን': 841,
#  'የሰይጣን': 842,
#  'ኦሮሞን': 843,
#  'በትግራይ': 844,
#  'አድርገው': 845,
#  'ማለቴ': 846,
#  'ሺ': 847,
#  'መጠበቅ': 848,
#  'የብሄር': 849,
#  'ፅጌ': 850,
#  'በዘር': 851,
#  'መሪዎች': 852,
#  'ኢሳያስ': 853,
#  'ለመናገር': 854,
#  'ያለህ': 855,
#  'ደግ': 856,
#  'ስድብ': 857,
#  'ባንተ': 858,
#  'አያስፈልግም': 859,
#  'አይገባም': 860,
#  'ጋዜጠኛ': 861,
#  'አ': 862,
#  'በአሁኑ': 863,
#  'ይቀጥላል': 864,
#  'የመጣ': 865,
#  'የእኛ': 866,
#  'ከአንተ': 867,
#  'የህግ': 868,
#  'ገርባ': 869,
#  'አርማ': 870,
#  'ውድ': 871,
#  'ብቅ': 872,
#  'በደል': 873,
#  'እናንተም': 874,
#  'የቀን': 875,
#  'ሰዎችን': 876,
#  'ሁን': 877,
#  'የሚችል': 878,
#  'ሚሊዮን': 879,
#  'በተግባር': 880,
#  'የሆነውን': 881,
#  'ሁለቱም': 882,
#  'በመንግስት': 883,
#  'በስተቀር': 884,
#  'መስጊድ': 885,
#  'ኡስታዝ': 886,
#  'ከኢትዮጵያ': 887,
#  'የሁሉም': 888,
#  'ሶስት': 889,
#  'ብትል': 890,
#  'ወንድ': 891,
#  'መፃፍ': 892,
#  'አመለካከት': 893,
#  'ከወያኔ': 894,
#  'ፖለቲካዊ': 895,
#  'እንደው': 896,
#  'ሆን': 897,
#  'ሰበብ': 898,
#  'መጠየቅ': 899,
#  'ን': 900,
#  'የጋራ': 901,
#  'በነገራችን': 902,
#  'ገብርዬ': 903,
#  'ፓርቲዎች': 904,
#  'ከሰው': 905,
#  'ነብስ': 906,
#  'ወይንም': 907,
#  'ሜዳ': 908,
#  'ድንግል': 909,
#  'የሰውን': 910,
#  'ኢትዮጵያውያን': 911,
#  'የአንተ': 912,
#  'ቀረ': 913,
#  'አንች': 914,
#  'ኢህአዴግ': 915,
#  'ሆዳም': 916,
#  'ጀግንነት': 917,
#  'ጋላ': 918,
#  'የጥላቻ': 919,
#  'ዜጎች': 920,
#  'ይበል': 921,
#  'በመጀመሪያ': 922,
#  'በወያኔ': 923,
#  'መንግስትን': 924,
#  'ይታወቃል': 925,
#  'አደራ': 926,
#  'ባለው': 927,
#  'አሳፋሪ': 928,
#  'ጀበል': 929,
#  'አህመዲን': 930,
#  'ጥበቡ': 931,
#  'አተ': 932,
#  'ነዋ': 933,
#  'የተባለው': 934,
#  'ይመጣል': 935,
#  'በሆነ': 936,
#  'ባህል': 937,
#  'እራስህን': 938,
#  'በኦሮሚያ': 939,
#  'ማንንም': 940,
#  'እናያለን': 941,
#  'እንደገና': 942,
#  'የግድ': 943,
#  'ባለበት': 944,
#  'መምራት': 945,
#  'ወያኔን': 946,
#  'ታከለ': 947,
#  'ፒኮክ': 948,
#  'ይገባዋል': 949,
#  'አሪፍ': 950,
#  'እማ': 951,
#  'ክልሎች': 952,
#  'ይኖራል': 953,
#  'በአደባባይ': 954,
#  'ፖስት': 955,
#  'የራሱ': 956,
#  'ታየ': 957,
#  'ግብፅ': 958,
#  'ሌቦች': 959,
#  'ስራው': 960,
#  'እንዲሆን': 961,
#  'ከህወሀት': 962,
#  'መቆም': 963,
#  'አማራው': 964,
#  'ውይ': 965,
#  'በቀላሉ': 966,
#  'እባብ': 967,
#  'ለማንም': 968,
#  'ጅብ': 969,
#  'ካለህ': 970,
#  'መድሀኒት': 971,
#  'ትናንት': 972,
#  'አንዱን': 973,
#  'የተነሳ': 974,
#  'አልነበረም': 975,
#  'ምኑ': 976,
#  'በሁሉም': 977,
#  'አክሱም': 978,
#  'ይመስገን': 979,
#  'የፓለቲካ': 980,
#  'ስብሰባ': 981,
#  'በምክንያት': 982,
#  'ቀዳዳ': 983,
#  'ይዘው': 984,
#  'በታች': 985,
#  'አውሬ': 986,
#  'መሀመድ': 987,
#  'መማር': 988,
#  'የጃዋር': 989,
#  'ያለን': 990,
#  'መጣ': 991,
#  'ወታደር': 992,
#  'የላቸውም': 993,
#  'መጀመርያ': 994,
#  'ዳቦ': 995,
#  'እድሜና': 996,
#  'ጥበብ': 997,
#  'ትርክት': 998,
#  'የለንም': 999,
#  'ከሆንክ': 1000,
#  ...}

# %%
len(word_dict)
# Out:
# 112887

# %%
from matplotlib import pyplot as plt

# %%
sequences=sentence_tokenizer.texts_to_sequences(sentences_shuffled)
length=[len(seq) for seq in sequences]

# %%
length.sort()
input_length_max=max(length)
avg_length=sum(length)/(len(length))
print(input_length_max,avg_length)
# Out:
# 254 18.032966666666667

# %%
length_sequence_section=[]
for i in range(1,11):
  idx=(len(length)-1)*i//10
  length_sequence_section.append(length[idx])
plt.plot([i for i in range(1,11)],length_sequence_section)

# %%
max_length=50

# %%
padded_sequence=tf.keras.preprocessing.sequence.pad_sequences(sequences,maxlen=max_length,padding="pre",truncating="pre")
labels=np.array(labels)

# %%
training_seq=padded_sequence[:int(len(padded_sequence)*.85)]
test_seq=padded_sequence[int(len(padded_sequence)*.85):]
training_label=labels_shuffled[:int(len(padded_sequence)*.85)]
test_label=labels_shuffled[int(len(padded_sequence)*.85):]

# %% [markdown]
# # Callbacks For tuning hyperparameters and early stopping

# %%
class StopCallBack(tf.keras.callbacks.Callback):

  def __init__(self,validation,training):
    self.validation=validation
    self.training=training

  def on_epoch_end(self,epochs,logs={}):
    if logs.get("accuracy")>=self.training and logs.get("val_accuracy")>=self.validation:
      self.model.stop_training=True

learning_scheduler_calback=tf.keras.callbacks.LearningRateScheduler(lambda epochs: 1e-8 * 10**(epochs/20))

# %% [markdown]
# # Model Creation

# %%
def creat_model():
  embedding_dims=16
  vocab_size=len(word_dict)+1
  model=tf.keras.Sequential([
  tf.keras.layers.Embedding(vocab_size, embedding_dims,input_shape=(max_length,)),
  tf.keras.layers.Dropout(.6),
  # tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32,return_sequences=True)),
  # tf.keras.layers.Dropout(.5),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
  tf.keras.layers.Dense(32,activation="relu"),
  tf.keras.layers.Dropout(.6),
  tf.keras.layers.Dense(16,activation="relu"),
  tf.keras.layers.Dropout(.6),
  tf.keras.layers.Dense(1,activation="sigmoid")])
  return model

# %%
print(sum(labels))
print(sum(training_label))
print(sum(test_label))
# Out:
# 15198
# 13573
# 1625

# %%
training_label=np.array(training_label)
test_label=np.array(test_label)

# %%
model=creat_model()
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_15 (Embedding)    (None, 50, 16)            1806208
#
#  dropout_22 (Dropout)        (None, 50, 16)            0
#
#  bidirectional_1 (Bidirectio  (None, 64)               12544
#  nal)
#
#  dense_20 (Dense)            (None, 32)                2080
#
#  dropout_23 (Dropout)        (None, 32)                0
#
#  dense_21 (Dense)            (None, 16)                528
#
#  dropout_24 (Dropout)        (None, 16)                0
#
#  dense_22 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 1,821,377
# Trainable params: 1,821,377
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
history=model.fit(training_seq,training_label,epochs=50,batch_size=512,validation_data=(test_seq,test_label))
# Out:
# Epoch 1/50
# 50/50 [==============================] - 5s 36ms/step - loss: 0.6923 - accuracy: 0.5236 - val_loss: 0.7036 - val_accuracy: 0.3611
# Epoch 2/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.6915 - accuracy: 0.5323 - val_loss: 0.7065 - val_accuracy: 0.3611
# Epoch 3/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.6879 - accuracy: 0.5344 - val_loss: 0.7051 - val_accuracy: 0.3611
# Epoch 4/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.6496 - accuracy: 0.6127 - val_loss: 0.5868 - val_accuracy: 0.7702
# Epoch 5/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.5519 - accuracy: 0.7398 - val_loss: 0.4789 - val_accuracy: 0.7882
# Epoch 6/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.4422 - accuracy: 0.8177 - val_loss: 0.4121 - val_accuracy: 0.8244
# Epoch 7/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.3467 - accuracy: 0.8676 - val_loss: 0.4091 - val_accuracy: 0.8384
# Epoch 8/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.2882 - accuracy: 0.8914 - val_loss: 0.4206 - val_accuracy: 0.8333
# Epoch 9/50
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2435 - accuracy: 0.9092 - val_loss: 0.4442 - val_accuracy: 0.8416
# Epoch 10/50
# 50/50 [==============================] - 1s 16ms/step - loss: 0.2145 - accuracy: 0.9207 - val_loss: 0.5053 - val_accuracy: 0.8396
# Epoch 11/50
# 50/50 [==============================] - 1s 14ms/step - loss: 0.1987 - accuracy: 0.9272 - val_loss: 0.5056 - val_accuracy: 0.8431
# Epoch 12/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1851 - accuracy: 0.9310 - val_loss: 0.5635 - val_accuracy: 0.8440
# Epoch 13/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1733 - accuracy: 0.9367 - val_loss: 0.5585 - val_accuracy: 0.8440
# Epoch 14/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1654 - accuracy: 0.9367 - val_loss: 0.5509 - val_accuracy: 0.8456
# Epoch 15/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1574 - accuracy: 0.9403 - val_loss: 0.5881 - val_accuracy: 0.8429
# Epoch 16/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1520 - accuracy: 0.9411 - val_loss: 0.6057 - val_accuracy: 0.8462
# Epoch 17/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1436 - accuracy: 0.9446 - val_loss: 0.6418 - val_accuracy: 0.8484
# Epoch 18/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1420 - accuracy: 0.9431 - val_loss: 0.6340 - val_accuracy: 0.8489
# Epoch 19/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1366 - accuracy: 0.9434 - val_loss: 0.8214 - val_accuracy: 0.8451
# Epoch 20/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1304 - accuracy: 0.9481 - val_loss: 0.7029 - val_accuracy: 0.8467
# Epoch 21/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1241 - accuracy: 0.9495 - val_loss: 0.7606 - val_accuracy: 0.8424
# Epoch 22/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1239 - accuracy: 0.9464 - val_loss: 0.8315 - val_accuracy: 0.8436
# Epoch 23/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1272 - accuracy: 0.9466 - val_loss: 0.7862 - val_accuracy: 0.8464
# Epoch 24/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1144 - accuracy: 0.9499 - val_loss: 0.8442 - val_accuracy: 0.8451
# Epoch 25/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1151 - accuracy: 0.9488 - val_loss: 0.8608 - val_accuracy: 0.8464
# Epoch 26/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1099 - accuracy: 0.9499 - val_loss: 1.0820 - val_accuracy: 0.8482
# Epoch 27/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1074 - accuracy: 0.9499 - val_loss: 0.8636 - val_accuracy: 0.8460
# Epoch 28/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1053 - accuracy: 0.9499 - val_loss: 0.9723 - val_accuracy: 0.8444
# Epoch 29/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1034 - accuracy: 0.9539 - val_loss: 1.1258 - val_accuracy: 0.8444
# Epoch 30/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1004 - accuracy: 0.9504 - val_loss: 1.0195 - val_accuracy: 0.8438
# Epoch 31/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.0997 - accuracy: 0.9535 - val_loss: 0.9879 - val_accuracy: 0.8436
# Epoch 32/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.0970 - accuracy: 0.9542 - val_loss: 1.0842 - val_accuracy: 0.8467
# Epoch 33/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0940 - accuracy: 0.9530 - val_loss: 1.1435 - val_accuracy: 0.8480
# Epoch 34/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.0943 - accuracy: 0.9535 - val_loss: 1.2202 - val_accuracy: 0.8493
# Epoch 35/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.0915 - accuracy: 0.9528 - val_loss: 1.1072 - val_accuracy: 0.8467
# Epoch 36/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.0914 - accuracy: 0.9541 - val_loss: 1.2853 - val_accuracy: 0.8469
# Epoch 37/50
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0906 - accuracy: 0.9531 - val_loss: 1.2373 - val_accuracy: 0.8442
# Epoch 38/50
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0877 - accuracy: 0.9549 - val_loss: 1.2683 - val_accuracy: 0.8456
# Epoch 39/50
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0858 - accuracy: 0.9544 - val_loss: 1.3899 - val_accuracy: 0.8471
# Epoch 40/50
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0847 - accuracy: 0.9548 - val_loss: 1.2991 - val_accuracy: 0.8444
# Epoch 41/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.0869 - accuracy: 0.9529 - val_loss: 1.4116 - val_accuracy: 0.8456
# Epoch 42/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0858 - accuracy: 0.9572 - val_loss: 1.4475 - val_accuracy: 0.8431
# Epoch 43/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.0854 - accuracy: 0.9554 - val_loss: 1.4472 - val_accuracy: 0.8462
# Epoch 44/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0856 - accuracy: 0.9569 - val_loss: 1.3977 - val_accuracy: 0.8451
# Epoch 45/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0846 - accuracy: 0.9569 - val_loss: 1.3923 - val_accuracy: 0.8489
# Epoch 46/50
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0863 - accuracy: 0.9547 - val_loss: 1.2927 - val_accuracy: 0.8476
# Epoch 47/50
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0865 - accuracy: 0.9562 - val_loss: 1.4552 - val_accuracy: 0.8473
# Epoch 48/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0820 - accuracy: 0.9562 - val_loss: 1.4682 - val_accuracy: 0.8464
# Epoch 49/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0844 - accuracy: 0.9564 - val_loss: 1.4406 - val_accuracy: 0.8460
# Epoch 50/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.0816 - accuracy: 0.9559 - val_loss: 1.6566 - val_accuracy: 0.8462

# %%
val_accuracy=history.history["val_accuracy"]
accuracy=history.history["accuracy"]
loss=history.history["loss"]

# %%
plt.plot(val_accuracy)
plt.plot(accuracy)
plt.plot(loss)

# %%
model_one_lstm=tf.keras.Sequential([
    tf.keras.layers.Embedding(len(word_dict)+1,10,input_length=50),
    tf.keras.layers.LSTM(2),
    tf.keras.layers.Dropout(.6),
    tf.keras.layers.Dense(1,activation="sigmoid")
])

# %%
model_one_lstm.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_12 (Embedding)    (None, 50, 10)            1128880
#
#  lstm_12 (LSTM)              (None, 2)                 104
#
#  dropout_17 (Dropout)        (None, 2)                 0
#
#  dense_14 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 1,128,987
# Trainable params: 1,128,987
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer=tf.keras.optimizers.experimental.RMSprop(learning_rate=0.001)
model_one_lstm.compile(loss="binary_crossentropy",metrics=["accuracy"],optimizer="adam")

# %%
history=model_one_lstm.fit(training_seq,training_label,epochs=100,batch_size=128,validation_data=(test_seq,test_label))
# Out:
# Epoch 1/100
# 200/200 [==============================] - 3s 9ms/step - loss: 0.6901 - accuracy: 0.5356 - val_loss: 0.6951 - val_accuracy: 0.4451
# Epoch 2/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.6542 - accuracy: 0.6134 - val_loss: 0.5884 - val_accuracy: 0.7640
# Epoch 3/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.5683 - accuracy: 0.6926 - val_loss: 0.5066 - val_accuracy: 0.8016
# Epoch 4/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.4892 - accuracy: 0.7401 - val_loss: 0.4547 - val_accuracy: 0.8251
# Epoch 5/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.4331 - accuracy: 0.7682 - val_loss: 0.4110 - val_accuracy: 0.8342
# Epoch 6/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.4012 - accuracy: 0.7810 - val_loss: 0.3936 - val_accuracy: 0.8404
# Epoch 7/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3772 - accuracy: 0.7909 - val_loss: 0.3821 - val_accuracy: 0.8436
# Epoch 8/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.3623 - accuracy: 0.7960 - val_loss: 0.3795 - val_accuracy: 0.8469
# Epoch 9/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3523 - accuracy: 0.7989 - val_loss: 0.3740 - val_accuracy: 0.8473
# Epoch 10/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3412 - accuracy: 0.8010 - val_loss: 0.3744 - val_accuracy: 0.8444
# Epoch 11/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3369 - accuracy: 0.7998 - val_loss: 0.3769 - val_accuracy: 0.8449
# Epoch 12/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3304 - accuracy: 0.8020 - val_loss: 0.3771 - val_accuracy: 0.8467
# Epoch 13/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3244 - accuracy: 0.8058 - val_loss: 0.3773 - val_accuracy: 0.8493
# Epoch 14/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3210 - accuracy: 0.8062 - val_loss: 0.3813 - val_accuracy: 0.8496
# Epoch 15/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3155 - accuracy: 0.8073 - val_loss: 0.3852 - val_accuracy: 0.8482
# Epoch 16/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3141 - accuracy: 0.8069 - val_loss: 0.3850 - val_accuracy: 0.8473
# Epoch 17/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3152 - accuracy: 0.8052 - val_loss: 0.3916 - val_accuracy: 0.8509
# Epoch 18/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3059 - accuracy: 0.8074 - val_loss: 0.3921 - val_accuracy: 0.8478
# Epoch 19/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3055 - accuracy: 0.8072 - val_loss: 0.3979 - val_accuracy: 0.8478
# Epoch 20/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3045 - accuracy: 0.8080 - val_loss: 0.3997 - val_accuracy: 0.8469
# Epoch 21/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3011 - accuracy: 0.8064 - val_loss: 0.4016 - val_accuracy: 0.8480
# Epoch 22/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2985 - accuracy: 0.8083 - val_loss: 0.4076 - val_accuracy: 0.8464
# Epoch 23/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2928 - accuracy: 0.8122 - val_loss: 0.4143 - val_accuracy: 0.8480
# Epoch 24/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.3006 - accuracy: 0.8062 - val_loss: 0.4203 - val_accuracy: 0.8469
# Epoch 25/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2964 - accuracy: 0.8089 - val_loss: 0.4197 - val_accuracy: 0.8471
# Epoch 26/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2903 - accuracy: 0.8092 - val_loss: 0.4321 - val_accuracy: 0.8491
# Epoch 27/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2926 - accuracy: 0.8086 - val_loss: 0.4319 - val_accuracy: 0.8491
# Epoch 28/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2891 - accuracy: 0.8124 - val_loss: 0.4351 - val_accuracy: 0.8520
# Epoch 29/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2923 - accuracy: 0.8069 - val_loss: 0.4423 - val_accuracy: 0.8500
# Epoch 30/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2879 - accuracy: 0.8110 - val_loss: 0.4480 - val_accuracy: 0.8509
# Epoch 31/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2913 - accuracy: 0.8107 - val_loss: 0.4465 - val_accuracy: 0.8502
# Epoch 32/100
# 200/200 [==============================] - 2s 9ms/step - loss: 0.2875 - accuracy: 0.8105 - val_loss: 0.4556 - val_accuracy: 0.8484
# Epoch 33/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2867 - accuracy: 0.8121 - val_loss: 0.4661 - val_accuracy: 0.8489
# Epoch 34/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2827 - accuracy: 0.8139 - val_loss: 0.4650 - val_accuracy: 0.8489
# Epoch 35/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2855 - accuracy: 0.8102 - val_loss: 0.4799 - val_accuracy: 0.8491
# Epoch 36/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2839 - accuracy: 0.8124 - val_loss: 0.4854 - val_accuracy: 0.8489
# Epoch 37/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2838 - accuracy: 0.8115 - val_loss: 0.4897 - val_accuracy: 0.8504
# Epoch 38/100
# 200/200 [==============================] - 2s 8ms/step - loss: 0.2830 - accuracy: 0.8134 - val_loss: 0.4836 - val_accuracy: 0.8478
# Epoch 39/100
# 200/200 [==============================] - 2s 10ms/step - loss: 0.2830 - accuracy: 0.8095 - val_loss: 0.4871 - val_accuracy: 0.8502
# Epoch 40/100
# 200/200 [==============================] - 2s 9ms/step - loss: 0.2847 - accuracy: 0.8098 - val_loss: 0.4965 - val_accuracy: 0.8482
# Epoch 41/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2813 - accuracy: 0.8123 - val_loss: 0.5114 - val_accuracy: 0.8513
# Epoch 42/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2808 - accuracy: 0.8141 - val_loss: 0.5048 - val_accuracy: 0.8509
# Epoch 43/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2857 - accuracy: 0.8065 - val_loss: 0.5112 - val_accuracy: 0.8489
# Epoch 44/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2820 - accuracy: 0.8116 - val_loss: 0.5201 - val_accuracy: 0.8491
# Epoch 45/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2834 - accuracy: 0.8096 - val_loss: 0.5255 - val_accuracy: 0.8531
# Epoch 46/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2829 - accuracy: 0.8076 - val_loss: 0.5296 - val_accuracy: 0.8513
# Epoch 47/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2855 - accuracy: 0.8084 - val_loss: 0.5317 - val_accuracy: 0.8511
# Epoch 48/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2824 - accuracy: 0.8111 - val_loss: 0.5315 - val_accuracy: 0.8487
# Epoch 49/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2823 - accuracy: 0.8104 - val_loss: 0.5387 - val_accuracy: 0.8504
# Epoch 50/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2782 - accuracy: 0.8135 - val_loss: 0.5578 - val_accuracy: 0.8507
# Epoch 51/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2786 - accuracy: 0.8118 - val_loss: 0.5621 - val_accuracy: 0.8493
# Epoch 52/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2797 - accuracy: 0.8144 - val_loss: 0.5562 - val_accuracy: 0.8513
# Epoch 53/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2801 - accuracy: 0.8082 - val_loss: 0.5683 - val_accuracy: 0.8518
# Epoch 54/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2820 - accuracy: 0.8075 - val_loss: 0.5640 - val_accuracy: 0.8518
# Epoch 55/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2841 - accuracy: 0.8091 - val_loss: 0.5693 - val_accuracy: 0.8540
# Epoch 56/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2783 - accuracy: 0.8131 - val_loss: 0.5791 - val_accuracy: 0.8504
# Epoch 57/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2783 - accuracy: 0.8133 - val_loss: 0.5639 - val_accuracy: 0.8509
# Epoch 58/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2770 - accuracy: 0.8118 - val_loss: 0.6099 - val_accuracy: 0.8511
# Epoch 59/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2790 - accuracy: 0.8130 - val_loss: 0.5721 - val_accuracy: 0.8504
# Epoch 60/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2799 - accuracy: 0.8120 - val_loss: 0.5907 - val_accuracy: 0.8513
# Epoch 61/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2779 - accuracy: 0.8133 - val_loss: 0.6149 - val_accuracy: 0.8502
# Epoch 62/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2827 - accuracy: 0.8111 - val_loss: 0.6080 - val_accuracy: 0.8500
# Epoch 63/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2776 - accuracy: 0.8148 - val_loss: 0.6057 - val_accuracy: 0.8509
# Epoch 64/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2812 - accuracy: 0.8096 - val_loss: 0.6125 - val_accuracy: 0.8516
# Epoch 65/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2831 - accuracy: 0.8074 - val_loss: 0.6132 - val_accuracy: 0.8520
# Epoch 66/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2808 - accuracy: 0.8094 - val_loss: 0.6109 - val_accuracy: 0.8529
# Epoch 67/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2777 - accuracy: 0.8135 - val_loss: 0.6160 - val_accuracy: 0.8516
# Epoch 68/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2770 - accuracy: 0.8104 - val_loss: 0.6235 - val_accuracy: 0.8513
# Epoch 69/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2779 - accuracy: 0.8131 - val_loss: 0.6373 - val_accuracy: 0.8500
# Epoch 70/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2769 - accuracy: 0.8145 - val_loss: 0.6392 - val_accuracy: 0.8500
# Epoch 71/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2791 - accuracy: 0.8117 - val_loss: 0.6320 - val_accuracy: 0.8511
# Epoch 72/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2797 - accuracy: 0.8131 - val_loss: 0.6367 - val_accuracy: 0.8518
# Epoch 73/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2716 - accuracy: 0.8197 - val_loss: 0.6433 - val_accuracy: 0.8491
# Epoch 74/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2785 - accuracy: 0.8101 - val_loss: 0.6379 - val_accuracy: 0.8487
# Epoch 75/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2837 - accuracy: 0.8079 - val_loss: 0.6290 - val_accuracy: 0.8458
# Epoch 76/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2791 - accuracy: 0.8126 - val_loss: 0.6427 - val_accuracy: 0.8482
# Epoch 77/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2781 - accuracy: 0.8122 - val_loss: 0.6544 - val_accuracy: 0.8502
# Epoch 78/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2783 - accuracy: 0.8111 - val_loss: 0.6509 - val_accuracy: 0.8480
# Epoch 79/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2790 - accuracy: 0.8120 - val_loss: 0.6525 - val_accuracy: 0.8476
# Epoch 80/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2771 - accuracy: 0.8143 - val_loss: 0.6551 - val_accuracy: 0.8471
# Epoch 81/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2752 - accuracy: 0.8146 - val_loss: 0.6606 - val_accuracy: 0.8482
# Epoch 82/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2794 - accuracy: 0.8105 - val_loss: 0.6585 - val_accuracy: 0.8493
# Epoch 83/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2773 - accuracy: 0.8139 - val_loss: 0.6603 - val_accuracy: 0.8491
# Epoch 84/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2793 - accuracy: 0.8111 - val_loss: 0.6668 - val_accuracy: 0.8487
# Epoch 85/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2791 - accuracy: 0.8106 - val_loss: 0.6709 - val_accuracy: 0.8496
# Epoch 86/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2791 - accuracy: 0.8096 - val_loss: 0.6649 - val_accuracy: 0.8504
# Epoch 87/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2781 - accuracy: 0.8118 - val_loss: 0.6699 - val_accuracy: 0.8511
# Epoch 88/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2777 - accuracy: 0.8111 - val_loss: 0.6759 - val_accuracy: 0.8504
# Epoch 89/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2777 - accuracy: 0.8135 - val_loss: 0.6702 - val_accuracy: 0.8498
# Epoch 90/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2793 - accuracy: 0.8098 - val_loss: 0.6767 - val_accuracy: 0.8482
# Epoch 91/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2775 - accuracy: 0.8114 - val_loss: 0.6776 - val_accuracy: 0.8498
# Epoch 92/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2723 - accuracy: 0.8149 - val_loss: 0.6806 - val_accuracy: 0.8489
# Epoch 93/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2759 - accuracy: 0.8166 - val_loss: 0.6885 - val_accuracy: 0.8496
# Epoch 94/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2762 - accuracy: 0.8120 - val_loss: 0.6906 - val_accuracy: 0.8471
# Epoch 95/100
# 200/200 [==============================] - 2s 8ms/step - loss: 0.2802 - accuracy: 0.8123 - val_loss: 0.6911 - val_accuracy: 0.8500
# Epoch 96/100
# 200/200 [==============================] - 2s 9ms/step - loss: 0.2736 - accuracy: 0.8127 - val_loss: 0.6857 - val_accuracy: 0.8511
# Epoch 97/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2786 - accuracy: 0.8082 - val_loss: 0.6917 - val_accuracy: 0.8504
# Epoch 98/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2769 - accuracy: 0.8129 - val_loss: 0.6904 - val_accuracy: 0.8504
# Epoch 99/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2810 - accuracy: 0.8106 - val_loss: 0.6973 - val_accuracy: 0.8522
# Epoch 100/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2795 - accuracy: 0.8129 - val_loss: 0.6914 - val_accuracy: 0.8496

# %%
val_accuracy=history.history["val_accuracy"]
accuracy=history.history["accuracy"]
loss=history.history["loss"]
plt.plot(val_accuracy)
plt.plot(accuracy)
plt.plot(loss)

# %%
def create_model_with_conv1D(vocab_size=100,embedding_dims=100,max_len=100):
  inputs=tf.keras.layers.Input(shape=(50,))
  x=tf.keras.layers.Embedding(len(word_dict)+1,100,input_length=max_len)(inputs)
  x=tf.keras.layers.Conv1D(32,4,activation="relu")(x)
  x=tf.keras.layers.GlobalAveragePooling1D()(x)
  x=tf.keras.layers.Dropout(.5)(x)

  # deleted the layers below because the dimensions didn't match
  # we can use lambda layer to expand the dims so that it matches the expected dims

  # x=tf.keras.layers.Conv1D(128,4,activation="relu")(x)
  # x=tf.keras.layers.GlobalAveragePooling1D()(x)
  # x=tf.keras.layers.Dropout(.5)(x)

  x=tf.keras.layers.Dense(16,activation="relu")(x)
  x=tf.keras.layers.Dropout(.3)(x)
  x=tf.keras.layers.Dense(8,activation="relu")(x)
  outputs=tf.keras.layers.Dense(1,activation="sigmoid")(x)
  model=tf.keras.Model(inputs=inputs,outputs=outputs)
  return model

# %%
model_2=create_model_with_conv1D()
model_2.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 50)]              0
#
#  embedding_13 (Embedding)    (None, 50, 100)           11288800
#
#  conv1d (Conv1D)             (None, 47, 32)            12832
#
#  global_average_pooling1d (G  (None, 32)               0
#  lobalAveragePooling1D)
#
#  dropout_18 (Dropout)        (None, 32)                0
#
#  dense_15 (Dense)            (None, 16)                528
#
#  dropout_19 (Dropout)        (None, 16)                0
#
#  dense_16 (Dense)            (None, 8)                 136
#
#  dense_17 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 11,302,305
# Trainable params: 11,302,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_2.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
history=model_2.fit(training_seq,training_label,epochs=50,batch_size=512,validation_data=(test_seq,test_label))
# Out:
# Epoch 1/50
# 50/50 [==============================] - 6s 19ms/step - loss: 0.6916 - accuracy: 0.5316 - val_loss: 0.7070 - val_accuracy: 0.3611
# Epoch 2/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.6807 - accuracy: 0.5384 - val_loss: 0.6759 - val_accuracy: 0.6191
# Epoch 3/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.5887 - accuracy: 0.7161 - val_loss: 0.5116 - val_accuracy: 0.8087
# Epoch 4/50
# 50/50 [==============================] - 1s 13ms/step - loss: 0.3882 - accuracy: 0.8528 - val_loss: 0.4313 - val_accuracy: 0.8402
# Epoch 5/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.2616 - accuracy: 0.9098 - val_loss: 0.4412 - val_accuracy: 0.8498
# Epoch 6/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.2093 - accuracy: 0.9321 - val_loss: 0.4619 - val_accuracy: 0.8520
# Epoch 7/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1787 - accuracy: 0.9418 - val_loss: 0.4825 - val_accuracy: 0.8540
# Epoch 8/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1564 - accuracy: 0.9487 - val_loss: 0.5039 - val_accuracy: 0.8518
# Epoch 9/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1389 - accuracy: 0.9527 - val_loss: 0.5276 - val_accuracy: 0.8513
# Epoch 10/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1247 - accuracy: 0.9549 - val_loss: 0.5532 - val_accuracy: 0.8487
# Epoch 11/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1146 - accuracy: 0.9579 - val_loss: 0.5790 - val_accuracy: 0.8500
# Epoch 12/50
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1044 - accuracy: 0.9592 - val_loss: 0.6163 - val_accuracy: 0.8516
# Epoch 13/50
# 50/50 [==============================] - 1s 14ms/step - loss: 0.1002 - accuracy: 0.9594 - val_loss: 0.6297 - val_accuracy: 0.8516
# Epoch 14/50
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0923 - accuracy: 0.9602 - val_loss: 0.6652 - val_accuracy: 0.8547
# Epoch 15/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0832 - accuracy: 0.9633 - val_loss: 0.7102 - val_accuracy: 0.8567
# Epoch 16/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0786 - accuracy: 0.9634 - val_loss: 0.7461 - val_accuracy: 0.8542
# Epoch 17/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0763 - accuracy: 0.9624 - val_loss: 0.8036 - val_accuracy: 0.8549
# Epoch 18/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0730 - accuracy: 0.9638 - val_loss: 0.8456 - val_accuracy: 0.8540
# Epoch 19/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0707 - accuracy: 0.9654 - val_loss: 0.8881 - val_accuracy: 0.8482
# Epoch 20/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0676 - accuracy: 0.9648 - val_loss: 0.9361 - val_accuracy: 0.8493
# Epoch 21/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0673 - accuracy: 0.9639 - val_loss: 0.9563 - val_accuracy: 0.8491
# Epoch 22/50
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0666 - accuracy: 0.9653 - val_loss: 0.9844 - val_accuracy: 0.8511
# Epoch 23/50
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0642 - accuracy: 0.9645 - val_loss: 1.0363 - val_accuracy: 0.8520
# Epoch 24/50
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0628 - accuracy: 0.9655 - val_loss: 1.0669 - val_accuracy: 0.8518
# Epoch 25/50
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0617 - accuracy: 0.9665 - val_loss: 1.0962 - val_accuracy: 0.8498
# Epoch 26/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0606 - accuracy: 0.9658 - val_loss: 1.1316 - val_accuracy: 0.8516
# Epoch 27/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0610 - accuracy: 0.9650 - val_loss: 1.1423 - val_accuracy: 0.8476
# Epoch 28/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0601 - accuracy: 0.9653 - val_loss: 1.1682 - val_accuracy: 0.8504
# Epoch 29/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0579 - accuracy: 0.9681 - val_loss: 1.2193 - val_accuracy: 0.8493
# Epoch 30/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0560 - accuracy: 0.9685 - val_loss: 1.2707 - val_accuracy: 0.8498
# Epoch 31/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0573 - accuracy: 0.9676 - val_loss: 1.2916 - val_accuracy: 0.8513
# Epoch 32/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0563 - accuracy: 0.9676 - val_loss: 1.3211 - val_accuracy: 0.8518
# Epoch 33/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0551 - accuracy: 0.9671 - val_loss: 1.3444 - val_accuracy: 0.8502
# Epoch 34/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0539 - accuracy: 0.9673 - val_loss: 1.3672 - val_accuracy: 0.8509
# Epoch 35/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0543 - accuracy: 0.9691 - val_loss: 1.3715 - val_accuracy: 0.8516
# Epoch 36/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0543 - accuracy: 0.9679 - val_loss: 1.4083 - val_accuracy: 0.8522
# Epoch 37/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0552 - accuracy: 0.9679 - val_loss: 1.3974 - val_accuracy: 0.8511
# Epoch 38/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0556 - accuracy: 0.9671 - val_loss: 1.4084 - val_accuracy: 0.8480
# Epoch 39/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0545 - accuracy: 0.9676 - val_loss: 1.4101 - val_accuracy: 0.8478
# Epoch 40/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0545 - accuracy: 0.9666 - val_loss: 1.4197 - val_accuracy: 0.8473
# Epoch 41/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0533 - accuracy: 0.9687 - val_loss: 1.4748 - val_accuracy: 0.8467
# Epoch 42/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0519 - accuracy: 0.9685 - val_loss: 1.4969 - val_accuracy: 0.8471
# Epoch 43/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0504 - accuracy: 0.9685 - val_loss: 1.5354 - val_accuracy: 0.8484
# Epoch 44/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0508 - accuracy: 0.9680 - val_loss: 1.5907 - val_accuracy: 0.8440
# Epoch 45/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0515 - accuracy: 0.9682 - val_loss: 1.6159 - val_accuracy: 0.8476
# Epoch 46/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0519 - accuracy: 0.9696 - val_loss: 1.6235 - val_accuracy: 0.8444
# Epoch 47/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0518 - accuracy: 0.9684 - val_loss: 1.6088 - val_accuracy: 0.8476
# Epoch 48/50
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0514 - accuracy: 0.9680 - val_loss: 1.6145 - val_accuracy: 0.8447
# Epoch 49/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0522 - accuracy: 0.9675 - val_loss: 1.6065 - val_accuracy: 0.8438
# Epoch 50/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0517 - accuracy: 0.9685 - val_loss: 1.6101 - val_accuracy: 0.8444

# %%
model_2.save("model_3.h5")

# %%
val_accuracy=history.history["val_accuracy"]
accuracy=history.history["accuracy"]
loss=history.history["loss"]
plt.plot(val_accuracy)
plt.plot(accuracy)
plt.plot(loss)

# %%
def creat_model_no_rnn():
  embedding_dims=16
  vocab_size=len(word_dict)+1
  inputs=tf.keras.layers.Input(shape=(50))
  x=tf.keras.layers.Embedding(vocab_size,embedding_dims,input_length=100)(inputs) #returns word embedding matrix for the input
  # insted of flatten averages over the columns
  x=tf.keras.layers.Dropout(.5)(x)
  x=tf.keras.layers.GlobalAveragePooling1D()(x)
  x= tf.keras.layers.Dense(24, activation='relu',kernel_regularizer=tf.keras.regularizers.l2())(x)
  x=tf.keras.layers.Dropout(.5)(x)
  outputs=tf.keras.layers.Dense(1, activation='sigmoid')(x)
  model=tf.keras.Model(inputs=inputs,outputs=outputs)
  return model

# %%
model_3=creat_model_no_rnn()
model_3.summary()
model_3.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 50)]              0
#
#  embedding_14 (Embedding)    (None, 50, 16)            1806208
#
#  dropout_20 (Dropout)        (None, 50, 16)            0
#
#  global_average_pooling1d_1   (None, 16)               0
#  (GlobalAveragePooling1D)
#
#  dense_18 (Dense)            (None, 24)                408
#
#  dropout_21 (Dropout)        (None, 24)                0
#
#  dense_19 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 1,806,641
# Trainable params: 1,806,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model_3.fit(training_seq,training_label,epochs=50,batch_size=512,validation_data=(test_seq,test_label))
val_accuracy=history.history["val_accuracy"]
accuracy=history.history["accuracy"]
loss=history.history["loss"]
plt.plot(val_accuracy)
plt.plot(accuracy)
plt.plot(loss)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.8589 - accuracy: 0.5276 - val_loss: 0.8443 - val_accuracy: 0.3611
# Epoch 2/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.8021 - accuracy: 0.5323 - val_loss: 0.7995 - val_accuracy: 0.3611
# Epoch 3/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.7634 - accuracy: 0.5323 - val_loss: 0.7705 - val_accuracy: 0.3611
# Epoch 4/50
# 50/50 [==============================] - 1s 10ms/step - loss: 0.7369 - accuracy: 0.5323 - val_loss: 0.7490 - val_accuracy: 0.3611
# Epoch 5/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.7192 - accuracy: 0.5323 - val_loss: 0.7349 - val_accuracy: 0.3611
# Epoch 6/50
# 50/50 [==============================] - 1s 14ms/step - loss: 0.7075 - accuracy: 0.5323 - val_loss: 0.7192 - val_accuracy: 0.3611
# Epoch 7/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.6997 - accuracy: 0.5340 - val_loss: 0.7188 - val_accuracy: 0.3611
# Epoch 8/50
# 50/50 [==============================] - 1s 13ms/step - loss: 0.6941 - accuracy: 0.5338 - val_loss: 0.7143 - val_accuracy: 0.3611
# Epoch 9/50
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6891 - accuracy: 0.5437 - val_loss: 0.7068 - val_accuracy: 0.3644
# Epoch 10/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.6834 - accuracy: 0.5744 - val_loss: 0.7015 - val_accuracy: 0.4211
# Epoch 11/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6755 - accuracy: 0.6215 - val_loss: 0.6877 - val_accuracy: 0.5833
# Epoch 12/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6626 - accuracy: 0.6656 - val_loss: 0.6746 - val_accuracy: 0.6616
# Epoch 13/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6473 - accuracy: 0.6977 - val_loss: 0.6582 - val_accuracy: 0.7133
# Epoch 14/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6276 - accuracy: 0.7244 - val_loss: 0.6311 - val_accuracy: 0.7820
# Epoch 15/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6080 - accuracy: 0.7399 - val_loss: 0.6250 - val_accuracy: 0.7498
# Epoch 16/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5896 - accuracy: 0.7594 - val_loss: 0.6083 - val_accuracy: 0.7649
# Epoch 17/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5692 - accuracy: 0.7799 - val_loss: 0.5839 - val_accuracy: 0.8073
# Epoch 18/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5508 - accuracy: 0.7933 - val_loss: 0.5779 - val_accuracy: 0.7976
# Epoch 19/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5336 - accuracy: 0.8086 - val_loss: 0.5583 - val_accuracy: 0.8198
# Epoch 20/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5189 - accuracy: 0.8220 - val_loss: 0.5625 - val_accuracy: 0.7893
# Epoch 21/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5022 - accuracy: 0.8308 - val_loss: 0.5421 - val_accuracy: 0.8256
# Epoch 22/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4873 - accuracy: 0.8424 - val_loss: 0.5277 - val_accuracy: 0.8258
# Epoch 23/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4741 - accuracy: 0.8471 - val_loss: 0.5257 - val_accuracy: 0.8291
# Epoch 24/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4615 - accuracy: 0.8593 - val_loss: 0.5157 - val_accuracy: 0.8340
# Epoch 25/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4496 - accuracy: 0.8616 - val_loss: 0.5097 - val_accuracy: 0.8367
# Epoch 26/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4391 - accuracy: 0.8687 - val_loss: 0.5044 - val_accuracy: 0.8364
# Epoch 27/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4279 - accuracy: 0.8767 - val_loss: 0.5027 - val_accuracy: 0.8344
# Epoch 28/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4176 - accuracy: 0.8808 - val_loss: 0.5017 - val_accuracy: 0.8287
# Epoch 29/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4075 - accuracy: 0.8840 - val_loss: 0.4880 - val_accuracy: 0.8413
# Epoch 30/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4009 - accuracy: 0.8870 - val_loss: 0.4831 - val_accuracy: 0.8420
# Epoch 31/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3924 - accuracy: 0.8917 - val_loss: 0.4847 - val_accuracy: 0.8369
# Epoch 32/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3860 - accuracy: 0.8954 - val_loss: 0.4774 - val_accuracy: 0.8438
# Epoch 33/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3768 - accuracy: 0.8972 - val_loss: 0.4686 - val_accuracy: 0.8491
# Epoch 34/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3692 - accuracy: 0.8999 - val_loss: 0.4707 - val_accuracy: 0.8442
# Epoch 35/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3620 - accuracy: 0.9042 - val_loss: 0.4666 - val_accuracy: 0.8471
# Epoch 36/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3547 - accuracy: 0.9066 - val_loss: 0.4645 - val_accuracy: 0.8451
# Epoch 37/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3490 - accuracy: 0.9095 - val_loss: 0.4605 - val_accuracy: 0.8480
# Epoch 38/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3451 - accuracy: 0.9112 - val_loss: 0.4553 - val_accuracy: 0.8498
# Epoch 39/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3384 - accuracy: 0.9117 - val_loss: 0.4559 - val_accuracy: 0.8493
# Epoch 40/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3328 - accuracy: 0.9125 - val_loss: 0.4519 - val_accuracy: 0.8511
# Epoch 41/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3271 - accuracy: 0.9161 - val_loss: 0.4532 - val_accuracy: 0.8478
# Epoch 42/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3225 - accuracy: 0.9159 - val_loss: 0.4464 - val_accuracy: 0.8509
# Epoch 43/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3162 - accuracy: 0.9180 - val_loss: 0.4485 - val_accuracy: 0.8513
# Epoch 44/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3138 - accuracy: 0.9178 - val_loss: 0.4452 - val_accuracy: 0.8527
# Epoch 45/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3070 - accuracy: 0.9220 - val_loss: 0.4420 - val_accuracy: 0.8502
# Epoch 46/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3040 - accuracy: 0.9231 - val_loss: 0.4434 - val_accuracy: 0.8527
# Epoch 47/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2998 - accuracy: 0.9237 - val_loss: 0.4418 - val_accuracy: 0.8538
# Epoch 48/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2951 - accuracy: 0.9261 - val_loss: 0.4413 - val_accuracy: 0.8538
# Epoch 49/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2926 - accuracy: 0.9248 - val_loss: 0.4374 - val_accuracy: 0.8522
# Epoch 50/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2877 - accuracy: 0.9285 - val_loss: 0.4362 - val_accuracy: 0.8527

# %%
model_3.save("model_4.h5")

# %%
model_lstm = tf.keras.Sequential([
    tf.keras.layers.Embedding(len(word_dict)+1, 15, input_length=50),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(10)),
    tf.keras.layers.Dropout(.6),
    tf.keras.layers.Dense(8, activation='relu',kernel_regularizer=tf.keras.regularizers.l2()),
    tf.keras.layers.Dropout(.5),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model_lstm.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model_lstm.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_20 (Embedding)    (None, 50, 15)            1693320
#
#  bidirectional_6 (Bidirectio  (None, 20)               2080
#  nal)
#
#  dropout_30 (Dropout)        (None, 20)                0
#
#  dense_29 (Dense)            (None, 8)                 168
#
#  dropout_31 (Dropout)        (None, 8)                 0
#
#  dense_30 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 1,695,577
# Trainable params: 1,695,577
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model_lstm.fit(training_seq,training_label,epochs=50,batch_size=512,validation_data=(test_seq,test_label))
val_accuracy=history.history["val_accuracy"]
accuracy=history.history["accuracy"]
loss=history.history["loss"]
plt.plot(val_accuracy)
plt.plot(accuracy)
plt.plot(loss)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 4s 26ms/step - loss: 0.7889 - accuracy: 0.5289 - val_loss: 0.7886 - val_accuracy: 0.3611
# Epoch 2/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.7589 - accuracy: 0.5315 - val_loss: 0.7575 - val_accuracy: 0.3633
# Epoch 3/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.7275 - accuracy: 0.5898 - val_loss: 0.6623 - val_accuracy: 0.7111
# Epoch 4/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.6471 - accuracy: 0.7053 - val_loss: 0.5577 - val_accuracy: 0.7947
# Epoch 5/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.5215 - accuracy: 0.8015 - val_loss: 0.4710 - val_accuracy: 0.8253
# Epoch 6/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.4184 - accuracy: 0.8581 - val_loss: 0.4545 - val_accuracy: 0.8371
# Epoch 7/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.3523 - accuracy: 0.8930 - val_loss: 0.4578 - val_accuracy: 0.8416
# Epoch 8/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.3150 - accuracy: 0.9082 - val_loss: 0.4441 - val_accuracy: 0.8502
# Epoch 9/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.2865 - accuracy: 0.9166 - val_loss: 0.4402 - val_accuracy: 0.8498
# Epoch 10/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.2648 - accuracy: 0.9237 - val_loss: 0.4671 - val_accuracy: 0.8484
# Epoch 11/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.2497 - accuracy: 0.9269 - val_loss: 0.4614 - val_accuracy: 0.8507
# Epoch 12/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.2347 - accuracy: 0.9312 - val_loss: 0.4692 - val_accuracy: 0.8491
# Epoch 13/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.2221 - accuracy: 0.9347 - val_loss: 0.4905 - val_accuracy: 0.8487
# Epoch 14/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.2133 - accuracy: 0.9353 - val_loss: 0.5012 - val_accuracy: 0.8487
# Epoch 15/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.2010 - accuracy: 0.9377 - val_loss: 0.5016 - val_accuracy: 0.8476
# Epoch 16/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1954 - accuracy: 0.9381 - val_loss: 0.5589 - val_accuracy: 0.8489
# Epoch 17/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1910 - accuracy: 0.9390 - val_loss: 0.5558 - val_accuracy: 0.8493
# Epoch 18/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1848 - accuracy: 0.9391 - val_loss: 0.5384 - val_accuracy: 0.8489
# Epoch 19/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1782 - accuracy: 0.9414 - val_loss: 0.5225 - val_accuracy: 0.8491
# Epoch 20/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1724 - accuracy: 0.9435 - val_loss: 0.5784 - val_accuracy: 0.8489
# Epoch 21/50
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1687 - accuracy: 0.9447 - val_loss: 0.5975 - val_accuracy: 0.8509
# Epoch 22/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1645 - accuracy: 0.9432 - val_loss: 0.6008 - val_accuracy: 0.8500
# Epoch 23/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1660 - accuracy: 0.9432 - val_loss: 0.6015 - val_accuracy: 0.8480
# Epoch 24/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1607 - accuracy: 0.9429 - val_loss: 0.6184 - val_accuracy: 0.8516
# Epoch 25/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1602 - accuracy: 0.9453 - val_loss: 0.6101 - val_accuracy: 0.8493
# Epoch 26/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1569 - accuracy: 0.9454 - val_loss: 0.6256 - val_accuracy: 0.8484
# Epoch 27/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1527 - accuracy: 0.9471 - val_loss: 0.5914 - val_accuracy: 0.8482
# Epoch 28/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1503 - accuracy: 0.9482 - val_loss: 0.6800 - val_accuracy: 0.8533
# Epoch 29/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1475 - accuracy: 0.9481 - val_loss: 0.6572 - val_accuracy: 0.8504
# Epoch 30/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1485 - accuracy: 0.9469 - val_loss: 0.6929 - val_accuracy: 0.8489
# Epoch 31/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1443 - accuracy: 0.9465 - val_loss: 0.6728 - val_accuracy: 0.8509
# Epoch 32/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1521 - accuracy: 0.9447 - val_loss: 0.5891 - val_accuracy: 0.8456
# Epoch 33/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1443 - accuracy: 0.9480 - val_loss: 0.6951 - val_accuracy: 0.8509
# Epoch 34/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1453 - accuracy: 0.9464 - val_loss: 0.6813 - val_accuracy: 0.8511
# Epoch 35/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1419 - accuracy: 0.9473 - val_loss: 0.7008 - val_accuracy: 0.8513
# Epoch 36/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1413 - accuracy: 0.9484 - val_loss: 0.6915 - val_accuracy: 0.8538
# Epoch 37/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1391 - accuracy: 0.9476 - val_loss: 0.7135 - val_accuracy: 0.8518
# Epoch 38/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1395 - accuracy: 0.9483 - val_loss: 0.7200 - val_accuracy: 0.8507
# Epoch 39/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1355 - accuracy: 0.9495 - val_loss: 0.7544 - val_accuracy: 0.8529
# Epoch 40/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1343 - accuracy: 0.9503 - val_loss: 0.7575 - val_accuracy: 0.8511
# Epoch 41/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1337 - accuracy: 0.9487 - val_loss: 0.7342 - val_accuracy: 0.8531
# Epoch 42/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1362 - accuracy: 0.9470 - val_loss: 0.7386 - val_accuracy: 0.8522
# Epoch 43/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1310 - accuracy: 0.9506 - val_loss: 0.7492 - val_accuracy: 0.8493
# Epoch 44/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1355 - accuracy: 0.9495 - val_loss: 0.6999 - val_accuracy: 0.8502
# Epoch 45/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1352 - accuracy: 0.9484 - val_loss: 0.7434 - val_accuracy: 0.8520
# Epoch 46/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1317 - accuracy: 0.9495 - val_loss: 0.7567 - val_accuracy: 0.8509
# Epoch 47/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1337 - accuracy: 0.9473 - val_loss: 0.7524 - val_accuracy: 0.8527
# Epoch 48/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1282 - accuracy: 0.9506 - val_loss: 0.7876 - val_accuracy: 0.8531
# Epoch 49/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1284 - accuracy: 0.9494 - val_loss: 0.7900 - val_accuracy: 0.8527
# Epoch 50/50
# 50/50 [==============================] - 1s 15ms/step - loss: 0.1291 - accuracy: 0.9481 - val_loss: 0.7942 - val_accuracy: 0.8500

# %%
model_lstm.save("")
